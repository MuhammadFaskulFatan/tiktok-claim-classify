# %% [markdown]
# # Exploratory Data Analysis
#
# **The purpose** of this notebook is to conduct exploratory data analysis on a provided data set. The mission is to continue the preliminary data investigation and perform further EDA on this data with the aim of learning more about the variables. Of particular interest is information related to what distinguishes claim videos from opinion videos.
#
# **The goal** is to explore/analyze the dataset and create visualizations.
#
# ---
#
# *This notebook has four parts:*
#
# **Part 1:** Imports and Load Data
#
# **Part 2:** Data Exploration
#
# **Part 3:** Build Visualizations
#
# **Part 4:** Determine Outliers

# %% [markdown]
# ## Part 1: Imports and Load Data

# %%
# Import packages for data manipulation
import numpy as np
import pandas as pd

# Import packages for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset into dataframe
data = pd.read_csv('data/tiktok_dataset.csv')

# %% [markdown]
# ## Part 2: Data Exploration

# %%
# Display and examine the first few rows of the dataframe
data.head()
# Out:
#    # claim_status    video_id  video_duration_sec
# 0  1        claim  7017666017                  59  \
# 1  2        claim  4014381136                  32
# 2  3        claim  9859838091                  31
# 3  4        claim  1866847991                  25
# 4  5        claim  7105231098                  19
#
#                             video_transcription_text verified_status
# 0  someone shared with me that drone deliveries a...    not verified  \
# 1  someone shared with me that there are more mic...    not verified
# 2  someone shared with me that american industria...    not verified
# 3  someone shared with me that the metro of st. p...    not verified
# 4  someone shared with me that the number of busi...    not verified
#
#   author_ban_status  video_view_count  video_like_count  video_share_count
# 0      under review          343296.0           19425.0              241.0  \
# 1            active          140877.0           77355.0            19034.0
# ...

# %%
# Get the size of the data
data.size
# Out:
# 232584

# %%
# Get the shape of the data
data.shape
# Out:
# (19382, 12)

# %%
# Get basic information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19382 entries, 0 to 19381
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #                         19382 non-null  int64
#  1   claim_status              19084 non-null  object
#  2   video_id                  19382 non-null  int64
#  3   video_duration_sec        19382 non-null  int64
#  4   video_transcription_text  19084 non-null  object
#  5   verified_status           19382 non-null  object
#  6   author_ban_status         19382 non-null  object
#  7   video_view_count          19084 non-null  float64
#  8   video_like_count          19084 non-null  float64
#  9   video_share_count         19084 non-null  float64
#  10  video_download_count      19084 non-null  float64
#  11  video_comment_count       19084 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 1.8+ MB

# %%
# Generate a table of descriptive statistics
data.describe()
# Out:
#                   #      video_id  video_duration_sec  video_view_count
# count  19382.000000  1.938200e+04        19382.000000      19084.000000  \
# mean    9691.500000  5.627454e+09           32.421732     254708.558688
# std     5595.245794  2.536440e+09           16.229967     322893.280814
# min        1.000000  1.234959e+09            5.000000         20.000000
# 25%     4846.250000  3.430417e+09           18.000000       4942.500000
# 50%     9691.500000  5.618664e+09           32.000000       9954.500000
# 75%    14536.750000  7.843960e+09           47.000000     504327.000000
# max    19382.000000  9.999873e+09           60.000000     999817.000000
#
#        video_like_count  video_share_count  video_download_count
# count      19084.000000       19084.000000          19084.000000  \
# mean       84304.636030       16735.248323           1049.429627
# std       133420.546814       32036.174350           2004.299894
# ...

# %% [markdown]
# ## Part 3: Build Visualizations

# %%
# plt.style.use('fivethirtyeight')
sns.set_theme()
sns.set_palette('colorblind')

# %% [markdown]
# ### video_duration_sec

# %%
# Create a boxplot to visualize distribution of `video_duration_sec`
fig, ax = plt.subplots(figsize=(8,1))
sns.boxplot(data=data, x='video_duration_sec', ax=ax).set_title('Video Duration (sec)')

plt.show()

# %%
# Create a histogram to further explore the distribution of this variable.
fig, ax = plt.subplots()
sns.histplot(data=data, x='video_duration_sec', bins=range(0,61,5), ax=ax).set_title('Video Duration (sec) Distribution')

plt.show()

# %% [markdown]
# The distribution is uniform and most videos are between 5 to 60 seconds.

# %% [markdown]
# ### video_view_count

# %%
# Create a boxplot to visualize distribution of `video_view_count`
fig, ax = plt.subplots(figsize=(8,1))
sns.boxplot(data=data, x='video_view_count', ax=ax).set_title('Video View Count')

plt.show()

# %%
# Create a histogram to further explore the distribution of this variable.
fig, ax = plt.subplots()
sns.histplot(data=data, x='video_view_count', bins=10, ax=ax).set_title('Video View Count Distribution')

plt.show()

# %% [markdown]
# The distribution is heavily right skewed and most videos have less than 1,000,000 views.

# %% [markdown]
# ### video_like_count

# %%
# Create a boxplot to visualize distribution of `video_like_count`
fig, ax = plt.subplots(figsize=(8,1))
sns.boxplot(data=data, x='video_like_count', ax=ax).set_title('Video Like Count')

plt.show()

# %%
# Create a histogram to further explore the distribution of this variable.
fig, ax = plt.subplots()
sns.histplot(data=data, x='video_like_count', bins=range(0, 700001, 100000), ax=ax).set_title('Video Like Count Distribution')

plt.show()

# %% [markdown]
# The distribution is heavily right skewed and most videos have below 100k likes.

# %% [markdown]
# ### video_comment_count

# %%
# Create a boxplot to visualize distribution of `video_comment_count`
fig, ax = plt.subplots(figsize=(8,1))
sns.boxplot(data=data, x='video_comment_count', ax=ax).set_title('Video Comment Count')

plt.show()

# %%
# Create a histogram to further explore the distribution of this variable.
fig, ax = plt.subplots()
sns.histplot(data=data, x='video_comment_count', bins=range(0, 3001, 100), ax=ax).set_title('Video Comment Count Distribution')

plt.show()

# %% [markdown]
# The distribution is heavily right skewed and most videos have below 100 comments.

# %% [markdown]
# ### video_share_count

# %%
# Create a boxplot to visualize distribution of `video_share_count`
fig, ax = plt.subplots(figsize=(8,1))
sns.boxplot(data=data, x='video_share_count', ax=ax).set_title('Video Share Count')

plt.show()

# %%
# Create a histogram to further explore the distribution of this variable.
fig, ax = plt.subplots()
sns.histplot(data=data, x='video_share_count', bins=range(0, 50001, 5000), ax=ax).set_title('Video Share Count Distribution')

plt.show()

# %% [markdown]
# The distribution is heavily right skewed and most videos have below 5000 shares.

# %% [markdown]
# ### video_download_count

# %%
# Create a boxplot to visualize distribution of `video_download_count`
fig, ax = plt.subplots(figsize=(8,1))
sns.boxplot(data=data, x='video_download_count', ax=ax).set_title('Video Download Count')

plt.show()

# %%
# Create a histogram to further explore the distribution of this variable.
fig, ax = plt.subplots()
sns.histplot(data=data, x='video_download_count', bins=range(0, 4001, 250), ax=ax).set_title('Video Download Count Distribution')

plt.show()

# %% [markdown]
# The distribution is heavily right skewed and most videos have below 250 downloads.

# %% [markdown]
# ### Claim status by verification status

# %%
# Create a histogram
fig, ax = plt.subplots(figsize=(9,4))
sns.countplot(data=data, x='claim_status', hue='verified_status', dodge=True, ax=ax)
ax.set_title('Claim Status Count per Verified Status - Counts')

plt.show()

# %% [markdown]
# There are less verified users than unverified users. There is also more verified users who post opinion videos than claim and this might increase the likehood for users to post opinions if they think this would get them verified.

# %% [markdown]
# ### Claim status by author ban status

# %%
# Create a histogram
fig, ax = plt.subplots(figsize=(9,4))
sns.countplot(data=data, x='claim_status', hue='author_ban_status', dodge=True,
              hue_order=['active','under review','banned'], palette={'active':'green', 'under review':'orange', 'banned':'red'},
              ax=ax)
ax.set_title('Claim Status per Authur Ban Status - Counts')

plt.show()

# %% [markdown]
# There is more active authors than those under review or banned for both claim and opinion. However, it seems like authors who post claim are more likely to be under review or get banned.

# %% [markdown]
# ### Median view counts by ban status

# %%
# Create a bar plot
ban_status_median = data.groupby('author_ban_status')['video_view_count'].median().reset_index()

fig, ax = plt.subplots()
sns.barplot(data=ban_status_median, x='author_ban_status', y='video_view_count',
            order=['active','under review','banned'], palette={'active':'green', 'under review':'orange', 'banned':'red'},
            ax=ax)
ax.set_title('Median View Count per Author Ban Status')

plt.show()

# %% [markdown]
# The median view count for active authors is significantly less than non-active authors. Non-active authors are also more likely to post claims so view count might be a good indicator of claim status.
#
# In other words, those with a lot of views $\rightarrow$ likely to be non-active authors $\rightarrow$ likely to post claims. Therefore, we can use view count as a indicator of claim status. We can check that in the following.

# %%
# Calculate the median view count for claim status.
data.groupby('claim_status')['video_view_count'].median().reset_index()
# Out:
#   claim_status  video_view_count
# 0        claim          501555.0
# 1      opinion            4953.0

# %% [markdown]
# ### Total views by claim status

# %%
# Create a pie graph
fig, ax = plt.subplots()
plt.pie(data.groupby('claim_status')['video_view_count'].sum(), labels=['claim','opinion'])
plt.title('Total Views per Claim Status')

plt.show()

# %%
# Check number of videos per claim status 
data.groupby('claim_status').size()
# Out:
# claim_status
# claim      9608
# opinion    9476
# dtype: int64

# %% [markdown]
# About 98-99% of all views are generated by claim videos even though the number of claim and opinion video are about the same.

# %% [markdown]
# ## Part 4: Determine Outliers
#
# When building predictive models, the presence of outliers can be problematic.
#
# In this TikTok dataset, the values for the count variables are not normally distributed. They are heavily skewed to the right. One way of modifying the outlier threshold is by calculating the **median** value for each variable and then adding 1.5 * IQR. This results in a threshold that is, in this case, much lower than the 3rd quartile.
#
# Write a for loop that iterates over the column names of each count variable. For each iteration:
# 1. Calculate the IQR of the column
# 2. Calculate the median of the column
# 3. Calculate the outlier threshold (median + 1.5 * IQR)
# 4. Calculate the numer of videos with a count in that column that exceeds the outlier threshold
# 5. Print "Number of outliers, {column name}: {outlier count}"

# %%
cols = ['video_view_count', 'video_like_count', 'video_share_count', 'video_download_count', 'video_comment_count']

for col in cols:
    q1 = data[col].quantile(0.25)
    q3 = data[col].quantile(0.75)
    iqr = q3 - q1
    outlier_threshold = (data[col].median()) + (1.5 * iqr)
    outlier_count = len(data[data[col]>outlier_threshold])
    print(f'Number of outliers for {col}: {outlier_count}')
# Out:
# Number of outliers for video_view_count: 2343
# Number of outliers for video_like_count: 3468
# Number of outliers for video_share_count: 3732
# Number of outliers for video_download_count: 3733
# Number of outliers for video_comment_count: 3882

# %% [markdown]
# ### Scatterplot

# %%
# Create a scatterplot of `video_like_count` versus `video_comment_count` according to 'claim_status'
fig, ax = plt.subplots(figsize=(7,5))
sns.scatterplot(data=data, x='video_like_count', y='video_comment_count', hue='claim_status', s=10)
ax.set_title('Video Like Count and Video Comment Count per Claim Status')

plt.show()

# %%
# Create a scatterplot of `video_like_count` versus `video_comment_count` for opinions only
opinion_data = data[data['claim_status']=='opinion']

fig, ax = plt.subplots(figsize=(7,5))
sns.scatterplot(data=opinion_data, x='video_like_count', y='video_comment_count', s=10)
ax.set_title('video_like_count vs video_comment_count - Opinions')

plt.show()
